# %%
from ahrs.filters import EKF
from ahrs import Quaternion
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from mango.tuner import Tuner
import time
import pickle 
from scipy.stats import uniform

# %% [markdown]
# ## Import Sample Head-Pose Data:

# %%
acc = pd.read_csv('Acc.csv',header=None).to_numpy()
gyro = pd.read_csv('Gyro.csv',header=None).to_numpy()
Or_GT = pd.read_csv('Or_GT.csv',header=None).to_numpy()
Euler_GT = np.zeros((Or_GT.shape[0],3))
for i in range(Or_GT.shape[0]):
    cur_quat = Quaternion(Or_GT[i,:])
    Euler_GT[i,:] = cur_quat.to_angles()   
plt.plot(Euler_GT[:,1]*57.2958,label='Elevation')
plt.plot(Euler_GT[:,2]*57.2958,label='Azimuth')
plt.xlabel('Sample Count')
plt.ylabel('Rotation (deg)')
plt.legend()
plt.title('Ground Truth Orientation')
plt.show()

# %% [markdown]
# ## Filter Performance (No tuning):

# %%
act_OR = EKF(gyr=gyro, acc=acc,frequency=100).Q
Euler_act = np.zeros((act_OR.shape[0],3))
for i in range(act_OR.shape[0]):
    cur_quat = Quaternion(act_OR[i,:])
    Euler_act[i,:] = cur_quat.to_angles() 
total_error = (np.mean(np.abs(Euler_GT[:,2]-Euler_act[:,2]))*57.2958) + (np.mean(np.abs(Euler_GT[:,1]-Euler_act[:,1]))*57.2958)
min_az_error = np.mean(np.abs(Euler_GT[:,2]-Euler_act[:,2]))*57.2958
min_ele_error = np.mean(np.abs(Euler_GT[:,1]-Euler_act[:,1]))*57.2958
print('MAE:',np.mean((min_az_error,min_ele_error)))
print('Azimuth Error: ',min_az_error)
print('Elevation Error: ',min_ele_error)
# Out:
# MAE: 67.53512090121188
# Azimuth Error:  77.77475575200774
# Elevation Error:  57.29548605041604

# %%
plt.plot(Euler_act[:,1]*57.2958,label='Elevation')
plt.plot(Euler_act[:,2]*57.2958,label='Azimuth')
plt.xlabel('Sample Count')
plt.ylabel('Rotation (deg)')
plt.legend()
plt.title('Untuned Filter Orientation')
plt.show()

# %% [markdown]
# ## Filter Performance (Tuned):

# %%
def objective_NN(acc_noise = 0, gyr_noise = 0):
    print('here')
    act_OR = EKF(gyr=gyro, acc=acc,frequency=100,noises=[acc_noise, gyr_noise, 0]).Q
    Euler_act = np.zeros((act_OR.shape[0],3))
    for i in range(act_OR.shape[0]):
        cur_quat = Quaternion(act_OR[i,:])
        Euler_act[i,:] = cur_quat.to_angles() 
    total_error = (np.mean(np.abs(Euler_GT[:,2]-Euler_act[:,2]))*57.2958) + (np.mean(np.abs(Euler_GT[:,1]-Euler_act[:,1]))*57.2958)
    return -total_error


def save_res(data, file_name):
    pickle.dump( data, open( file_name, "wb" ) )
    
param_dict = {
    'acc_noise': uniform(0, 1),
    'gyr_noise': uniform(0, 1)
}

def objfunc(args_list):

    objective_evaluated = []
    
    start_time = time.time()
    
    for hyper_par in args_list:
        acc_noise = hyper_par['acc_noise']
        gyr_noise = hyper_par['gyr_noise']
            
        objective = objective_NN(acc_noise = acc_noise,gyr_noise = gyr_noise)
        objective_evaluated.append(objective)
        
        end_time = time.time()
        print('objective:', objective, ' time:',end_time-start_time)
        
    return objective_evaluated

conf_Dict = dict()
conf_Dict['batch_size'] = 1
conf_Dict['num_iteration'] = 50
conf_Dict['initial_random']= 5
tuner = Tuner(param_dict, objfunc,conf_Dict)
all_runs = []
results = tuner.maximize()
all_runs.append(results)
save_res(all_runs,'IEKF_log.p')
# Out:
# here
# objective: -133.7491482592559  time: 0.23394393920898438
# here
# objective: -134.92004648778166  time: 0.46817970275878906
# here
# objective: -134.9948919608887  time: 0.70235276222229
# here
# objective: -132.53484032873357  time: 0.9381253719329834
# here
# objective: -134.33581391189924  time: 1.1737656593322754
#   0%|          | 0/50 [00:00<?, ?it/s]
# here
# objective: -135.87568465029966  time: 0.24187517166137695
# here
# objective: -134.14256070928272  time: 0.24152088165283203
# here
# objective: -134.20609773222372  time: 0.24532723426818848
# here
# objective: -133.11788303606446  time: 0.3004622459411621
# here
# objective: -169.87604688904253  time: 0.304152250289917
# here
# objective: -135.7070792469005  time: 0.24163150787353516
# here
# objective: -131.83481186435813  time: 0.2817845344543457
# here
# objective: -131.9143186054302  time: 0.2557494640350342
# here
# objective: -132.90908488379353  time: 0.31142258644104004
# here
# objective: -133.8176167913366  time: 0.2422800064086914
# here
# objective: -135.21830623363752  time: 0.2469322681427002
# here
# objective: -135.1164776869531  time: 0.255826473236084
# here
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2828577/2467063532.py in <module>
#      42 tuner = Tuner(param_dict, objfunc,conf_Dict)
#      43 all_runs = []
# ---> 44 results = tuner.maximize()
#      45 all_runs.append(results)
#      46 save_res(all_runs,'IEKF_log.p')
#
# ~/swapnil_debug/lib/python3.8/site-packages/mango/tuner.py in maximize(self)
#     146
#     147     def maximize(self):
# --> 148         return self.run()
#     149
#     150     def minimize(self):
#
# ~/swapnil_debug/lib/python3.8/site-packages/mango/tuner.py in run(self)
#     137     def run(self):
#     138         if self.config.is_bayesian:
# --> 139             self.results = self.runBayesianOptimizer()
#     140         elif self.config.is_random:
#     141             self.results = self.runRandomOptimizer()
#
# ~/swapnil_debug/lib/python3.8/site-packages/mango/tuner.py in runBayesianOptimizer(self)
#     229
#     230             # Evaluate the Objective function
# --> 231             X_next_list, Y_next_list = self.runUserObjective(X_next_PS)
#     232
#     233             # keep track of all parameters that failed
#
# ~/swapnil_debug/lib/python3.8/site-packages/mango/tuner.py in runUserObjective(self, X_next_PS)
#     321         # initially assuming entire X_next_PS is evaluated and returned results are only Y values
#     322         X_list_evaluated = X_next_PS
# --> 323         results = self.objective_function(X_next_PS)
#     324         Y_list_evaluated = results
#     325
#
# /tmp/ipykernel_2828577/2467063532.py in objfunc(args_list)
#      28         gyr_noise = hyper_par['gyr_noise']
#      29
# ---> 30         objective = objective_NN(acc_noise = acc_noise,gyr_noise = gyr_noise)
#      31         objective_evaluated.append(objective)
#      32
#
# /tmp/ipykernel_2828577/2467063532.py in objective_NN(acc_noise, gyr_noise)
#       1 def objective_NN(acc_noise = 0, gyr_noise = 0):
#       2     print('here')
# ----> 3     act_OR = EKF(gyr=gyro, acc=acc,frequency=100,noises=[acc_noise, gyr_noise, 0]).Q
#       4     Euler_act = np.zeros((act_OR.shape[0],3))
#       5     for i in range(act_OR.shape[0]):
#
# ~/swapnil_debug/lib/python3.8/site-packages/ahrs/filters/ekf.py in __init__(self, gyr, acc, mag, frequency, frame, **kwargs)
#     999         # Process of data is given
#    1000         if self.gyr is not None and self.acc is not None:
# -> 1001             self.Q = self._compute_all(self.frame)
#    1002
#    1003     def _set_measurement_noise_covariance(self, **kw) -> np.ndarray:
#
# ~/swapnil_debug/lib/python3.8/site-packages/ahrs/filters/ekf.py in _compute_all(self, frame)
#    1069         # EKF Loop over all data
#    1070         for t in range(1, num_samples):
# -> 1071             Q[t] = self.update(Q[t-1], self.gyr[t], self.acc[t])
#    1072         return Q
#    1073
#
# ~/swapnil_debug/lib/python3.8/site-packages/ahrs/filters/ekf.py in update(self, q, gyr, acc, mag)
#    1292         F   = self.dfdq(g)                  # Linearized Fundamental Matrix
#    1293         W   = 0.5*self.Dt * np.r_[[-q[1:]], q[0]*np.identity(3) + skew(q[1:])]  # Jacobian W = df/dω
# -> 1294         Q_t = 0.5*self.Dt * self.g_noise * W@W.T    # Process Noise Covariance
#    1295         P_t = F@self.P@F.T + Q_t            # Predicted Covariance Matrix
#    1296         # ----- Correction -----
#
# KeyboardInterrupt:

# %%
act_OR = EKF(gyr=gyro, acc=acc,frequency=100,noises=[results['best_params']['acc_noise'],
                                                     results['best_params']['gyr_noise'],0  ]).Q
Euler_act = np.zeros((act_OR.shape[0],3))
for i in range(act_OR.shape[0]):
    cur_quat = Quaternion(act_OR[i,:])
    Euler_act[i,:] = cur_quat.to_angles() 
total_error = (np.mean(np.abs(Euler_GT[:,2]-Euler_act[:,2]))*57.2958) + (np.mean(np.abs(Euler_GT[:,1]-Euler_act[:,1]))*57.2958)
min_az_error = np.mean(np.abs(Euler_GT[:,2]-Euler_act[:,2]))*57.2958
min_ele_error = np.mean(np.abs(Euler_GT[:,1]-Euler_act[:,1]))*57.2958
print('MAE:',np.mean((min_az_error,min_ele_error)))
print('Azimuth Error: ',min_az_error)
print('Elevation Error: ',min_ele_error)
# Out:
# MAE: 65.82939191065348
# Azimuth Error:  74.38224048173778
# Elevation Error:  57.276543339569194

# %%
plt.plot(Euler_GT[:,2]*57.2958,label='GT')
plt.plot(Euler_act[:,2]*57.2958,label='Predicted')
plt.xlabel('Sample Count')
plt.ylabel('Rotation (deg)')
plt.legend()
plt.title('Azimuth Head-Pose (Tuned)')
plt.show()

# %%
plt.plot(Euler_GT[:,1]*57.2958,label='GT')
plt.plot(Euler_act[:,1]*57.2958,label='Predicted')
plt.xlabel('Sample Count')
plt.ylabel('Rotation (deg)')
plt.legend()
plt.title('Elevation Head-Pose (Tuned)')
plt.show()
